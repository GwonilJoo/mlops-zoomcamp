# %%
import pandas as pd
import seaborn as sns

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Q1. Downloading the data
#
# We'll use the same NYC taxi dataset, but instead of "Green Taxi Trip Records", we'll use "For-Hire Vehicle Trip Records".
#
# Download the data for January and February 2021.
#
# Note that you need "For-Hire Vehicle Trip Records", not "High Volume For-Hire Vehicle Trip Records".
#
# Read the data for January. How many records are there?

# %%
df = pd.read_parquet('../data/fhv_tripdata_2021-01.parquet')

# %%
df
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 0                     B00009 2021-01-01 00:27:00 2021-01-01 00:44:00
# 1                     B00009 2021-01-01 00:50:00 2021-01-01 01:07:00
# 2                     B00013 2021-01-01 00:01:00 2021-01-01 01:51:00
# 3                     B00037 2021-01-01 00:13:09 2021-01-01 00:21:26
# 4                     B00037 2021-01-01 00:38:31 2021-01-01 00:53:44
# ...                      ...                 ...                 ...
# 1154107               B03266 2021-01-31 23:43:03 2021-01-31 23:51:48
# 1154108               B03284 2021-01-31 23:50:27 2021-02-01 00:48:03
# 1154109      B03285          2021-01-31 23:13:46 2021-01-31 23:29:58
# 1154110      B03285          2021-01-31 23:58:03 2021-02-01 00:17:29
# 1154111               B03321 2021-01-31 23:39:00 2021-02-01 00:15:00
#
#          PUlocationID  DOlocationID SR_Flag Affiliated_base_number
# 0                 NaN           NaN    None                 B00009
# 1                 NaN           NaN    None                 B00009
# 2                 NaN           NaN    None                 B00013
# 3                 NaN          72.0    None                 B00037
# 4                 NaN          61.0    None                 B00037
# ...               ...           ...     ...                    ...
# 1154107           7.0           7.0    None                 B03266
# 1154108          44.0          91.0    None
# 1154109         171.0         171.0    None        B03285
# 1154110          15.0          15.0    None        B03285
# 1154111           NaN           NaN    None                 B03321
#
# [1154112 rows x 7 columns]

# %% [markdown]
# ## Q2. Computing duration
# Now let's compute the duration variable. It should contain the duration of a ride in minutes.
#
# What's the average trip duration in January?

# %%
df['duration'] = df.dropOff_datetime - df.pickup_datetime
df['duration'] = df.duration.dt.total_seconds() / 60

# %%
df['duration']
# Out:
# 0           17.000000
# 1           17.000000
# 2          110.000000
# 3            8.283333
# 4           15.216667
#               ...
# 1154107      8.750000
# 1154108     57.600000
# 1154109     16.200000
# 1154110     19.433333
# 1154111     36.000000
# Name: duration, Length: 1154112, dtype: float64

# %%
df.duration.mean()
# Out:
# 19.167224093791006

# %% [markdown]
# ## Data preparation
#
# Check the distribution of the duration variable. There are some outliers.
#
# Let's remove them and keep only the records where the duration was between 1 and 60 minutes (inclusive).
#
# How many records did you drop?

# %%
df = df[(df['duration'] >= 1) & (df['duration'] <= 60)]
df
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 0                     B00009 2021-01-01 00:27:00 2021-01-01 00:44:00
# 1                     B00009 2021-01-01 00:50:00 2021-01-01 01:07:00
# 3                     B00037 2021-01-01 00:13:09 2021-01-01 00:21:26
# 4                     B00037 2021-01-01 00:38:31 2021-01-01 00:53:44
# 5                     B00037 2021-01-01 00:59:02 2021-01-01 01:08:05
# ...                      ...                 ...                 ...
# 1154107               B03266 2021-01-31 23:43:03 2021-01-31 23:51:48
# 1154108               B03284 2021-01-31 23:50:27 2021-02-01 00:48:03
# 1154109      B03285          2021-01-31 23:13:46 2021-01-31 23:29:58
# 1154110      B03285          2021-01-31 23:58:03 2021-02-01 00:17:29
# 1154111               B03321 2021-01-31 23:39:00 2021-02-01 00:15:00
#
#          PUlocationID  DOlocationID SR_Flag Affiliated_base_number   duration
# 0                 NaN           NaN    None                 B00009  17.000000
# 1                 NaN           NaN    None                 B00009  17.000000
# 3                 NaN          72.0    None                 B00037   8.283333
# 4                 NaN          61.0    None                 B00037  15.216667
# 5                 NaN          71.0    None                 B00037   9.050000
# ...               ...           ...     ...                    ...        ...
# 1154107           7.0           7.0    None                 B03266   8.750000
# 1154108          44.0          91.0    None                         57.600000
# 1154109         171.0         171.0    None        B03285           16.200000
# 1154110          15.0          15.0    None        B03285           19.433333
# 1154111           NaN           NaN    None                 B03321  36.000000
#
# [1109826 rows x 8 columns]

# %% [markdown]
# ## Q3. Missing values
#
# The features we'll use for our model are the pickup and dropoff location IDs.
#
# But they have a lot of missing values there. Let's replace them with "-1".
#
# What's the fractions of missing values for the pickup location ID? I.e. fraction of "-1"s after you filled the NAs.

# %%
categorical = ['PUlocationID', 'DOlocationID']

df[categorical] = df[categorical].fillna(-1).astype('int')
# Out:
# /tmp/ipykernel_549463/3155089242.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[categorical] = df[categorical].fillna(-1).astype('int')

# %%
len(df[df.PUlocationID == -1]) / len(df)
# Out:
# 0.8352732770722617

# %% [markdown]
# ## Q4. One-hot encoding
# Let's apply one-hot encoding to the pickup and dropoff location IDs. We'll use only these two features for our model.
#
# - Turn the dataframe into a list of dictionaries
# - Fit a dictionary vectorizer
# - Get a feature matrix from it
#
# What's the dimensionality of this matrix? (The number of columns).

# %%
#train_dicts = df[categorical].to_dict(orient='records')
train_dicts = df[categorical].astype('str').to_dict(orient='records')
train_dicts
# Out:
# [{'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '71'},
#  {'PUlocationID': '-1', 'DOlocationID': '91'},
#  {'PUlocationID': '-1', 'DOlocationID': '39'},
#  {'PUlocationID': '-1', 'DOlocationID': '37'},
#  {'PUlocationID': '-1', 'DOlocationID': '39'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '89'},
#  {'PUlocationID': '-1', 'DOlocationID': '177'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '67'},
#  {'PUlocationID': '-1', 'DOlocationID': '22'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '188'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '122'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '77'},
#  {'PUlocationID': '236', 'DOlocationID': '237'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '196', 'DOlocationID': '196'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '-1', 'DOlocationID': '126'},
#  {'PUlocationID': '-1', 'DOlocationID': '119'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '174'},
#  {'PUlocationID': '-1', 'DOlocationID': '248'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '42'},
#  {'PUlocationID': '-1', 'DOlocationID': '248'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '32'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '126'},
#  {'PUlocationID': '-1', 'DOlocationID': '127'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '121'},
#  {'PUlocationID': '-1', 'DOlocationID': '240'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '248'},
#  {'PUlocationID': '-1', 'DOlocationID': '20'},
#  {'PUlocationID': '-1', 'DOlocationID': '242'},
#  {'PUlocationID': '-1', 'DOlocationID': '200'},
#  {'PUlocationID': '-1', 'DOlocationID': '182'},
#  {'PUlocationID': '-1', 'DOlocationID': '208'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '70'},
#  {'PUlocationID': '-1', 'DOlocationID': '70'},
#  {'PUlocationID': '-1', 'DOlocationID': '129'},
#  {'PUlocationID': '-1', 'DOlocationID': '77'},
#  {'PUlocationID': '252', 'DOlocationID': '16'},
#  {'PUlocationID': '15', 'DOlocationID': '252'},
#  {'PUlocationID': '165', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '42'},
#  {'PUlocationID': '-1', 'DOlocationID': '223'},
#  {'PUlocationID': '-1', 'DOlocationID': '78'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '136'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '167'},
#  {'PUlocationID': '70', 'DOlocationID': '173'},
#  {'PUlocationID': '173', 'DOlocationID': '173'},
#  {'PUlocationID': '260', 'DOlocationID': '82'},
#  {'PUlocationID': '143', 'DOlocationID': '142'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '159'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '136'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '147'},
#  {'PUlocationID': '-1', 'DOlocationID': '116'},
#  {'PUlocationID': '115', 'DOlocationID': '206'},
#  {'PUlocationID': '221', 'DOlocationID': '115'},
#  {'PUlocationID': '115', 'DOlocationID': '245'},
#  {'PUlocationID': '206', 'DOlocationID': '206'},
#  {'PUlocationID': '221', 'DOlocationID': '221'},
#  {'PUlocationID': '206', 'DOlocationID': '187'},
#  {'PUlocationID': '206', 'DOlocationID': '206'},
#  {'PUlocationID': '221', 'DOlocationID': '206'},
#  {'PUlocationID': '206', 'DOlocationID': '187'},
#  {'PUlocationID': '206', 'DOlocationID': '187'},
#  {'PUlocationID': '206', 'DOlocationID': '206'},
#  {'PUlocationID': '206', 'DOlocationID': '221'},
#  {'PUlocationID': '206', 'DOlocationID': '221'},
#  {'PUlocationID': '115', 'DOlocationID': '206'},
#  {'PUlocationID': '206', 'DOlocationID': '221'},
#  {'PUlocationID': '206', 'DOlocationID': '221'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '78'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '258'},
#  {'PUlocationID': '-1', 'DOlocationID': '210'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '37'},
#  {'PUlocationID': '-1', 'DOlocationID': '258'},
#  {'PUlocationID': '-1', 'DOlocationID': '70'},
#  {'PUlocationID': '181', 'DOlocationID': '189'},
#  {'PUlocationID': '189', 'DOlocationID': '181'},
#  {'PUlocationID': '181', 'DOlocationID': '228'},
#  {'PUlocationID': '166', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '89'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '222'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '247'},
#  {'PUlocationID': '-1', 'DOlocationID': '119'},
#  {'PUlocationID': '-1', 'DOlocationID': '71'},
#  {'PUlocationID': '-1', 'DOlocationID': '85'},
#  {'PUlocationID': '-1', 'DOlocationID': '71'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '37'},
#  {'PUlocationID': '-1', 'DOlocationID': '198'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '89'},
#  {'PUlocationID': '-1', 'DOlocationID': '256'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '71'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '10'},
#  {'PUlocationID': '-1', 'DOlocationID': '66'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '49'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '188'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '77'},
#  {'PUlocationID': '-1', 'DOlocationID': '77'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '232'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '77'},
#  {'PUlocationID': '-1', 'DOlocationID': '77'},
#  {'PUlocationID': '-1', 'DOlocationID': '108'},
#  {'PUlocationID': '-1', 'DOlocationID': '152'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '37'},
#  {'PUlocationID': '-1', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '91'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '220'},
#  {'PUlocationID': '-1', 'DOlocationID': '174'},
#  {'PUlocationID': '-1', 'DOlocationID': '153'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '3'},
#  {'PUlocationID': '-1', 'DOlocationID': '241'},
#  {'PUlocationID': '-1', 'DOlocationID': '265'},
#  {'PUlocationID': '-1', 'DOlocationID': '200'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '220'},
#  {'PUlocationID': '-1', 'DOlocationID': '241'},
#  {'PUlocationID': '-1', 'DOlocationID': '136'},
#  {'PUlocationID': '-1', 'DOlocationID': '119'},
#  {'PUlocationID': '-1', 'DOlocationID': '106'},
#  {'PUlocationID': '-1', 'DOlocationID': '37'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '116'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '141'},
#  {'PUlocationID': '-1', 'DOlocationID': '141'},
#  {'PUlocationID': '-1', 'DOlocationID': '113'},
#  {'PUlocationID': '-1', 'DOlocationID': '265'},
#  {'PUlocationID': '129', 'DOlocationID': '129'},
#  {'PUlocationID': '-1', 'DOlocationID': '196'},
#  {'PUlocationID': '-1', 'DOlocationID': '132'},
#  {'PUlocationID': '-1', 'DOlocationID': '10'},
#  {'PUlocationID': '-1', 'DOlocationID': '134'},
#  {'PUlocationID': '-1', 'DOlocationID': '134'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '28'},
#  {'PUlocationID': '-1', 'DOlocationID': '129'},
#  {'PUlocationID': '-1', 'DOlocationID': '258'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '258'},
#  {'PUlocationID': '-1', 'DOlocationID': '102'},
#  {'PUlocationID': '-1', 'DOlocationID': '130'},
#  {'PUlocationID': '-1', 'DOlocationID': '167'},
#  {'PUlocationID': '-1', 'DOlocationID': '136'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '152'},
#  {'PUlocationID': '-1', 'DOlocationID': '3'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '136'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '119'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '243'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '-1', 'DOlocationID': '243'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '147'},
#  {'PUlocationID': '-1', 'DOlocationID': '89'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '47'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '32'},
#  {'PUlocationID': '-1', 'DOlocationID': '126'},
#  {'PUlocationID': '-1', 'DOlocationID': '167'},
#  {'PUlocationID': '-1', 'DOlocationID': '147'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '248'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '47'},
#  {'PUlocationID': '-1', 'DOlocationID': '32'},
#  {'PUlocationID': '-1', 'DOlocationID': '119'},
#  {'PUlocationID': '-1', 'DOlocationID': '147'},
#  {'PUlocationID': '-1', 'DOlocationID': '198'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '116'},
#  {'PUlocationID': '-1', 'DOlocationID': '116'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '142', 'DOlocationID': '142'},
#  {'PUlocationID': '142', 'DOlocationID': '200'},
#  {'PUlocationID': '211', 'DOlocationID': '107'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '189'},
#  {'PUlocationID': '-1', 'DOlocationID': '112'},
#  {'PUlocationID': '-1', 'DOlocationID': '40'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '21'},
#  {'PUlocationID': '-1', 'DOlocationID': '241'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '78'},
#  {'PUlocationID': '-1', 'DOlocationID': '153'},
#  {'PUlocationID': '-1', 'DOlocationID': '153'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '247'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '174'},
#  {'PUlocationID': '-1', 'DOlocationID': '78'},
#  {'PUlocationID': '-1', 'DOlocationID': '247'},
#  {'PUlocationID': '-1', 'DOlocationID': '75'},
#  {'PUlocationID': '-1', 'DOlocationID': '42'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '247'},
#  {'PUlocationID': '-1', 'DOlocationID': '247'},
#  {'PUlocationID': '-1', 'DOlocationID': '243'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '174'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '212'},
#  {'PUlocationID': '-1', 'DOlocationID': '212'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '-1', 'DOlocationID': '167'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '243'},
#  {'PUlocationID': '-1', 'DOlocationID': '3'},
#  {'PUlocationID': '-1', 'DOlocationID': '212'},
#  {'PUlocationID': '-1', 'DOlocationID': '248'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '126'},
#  {'PUlocationID': '-1', 'DOlocationID': '75'},
#  {'PUlocationID': '-1', 'DOlocationID': '119'},
#  {'PUlocationID': '-1', 'DOlocationID': '159'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '241'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '126'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '78'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '59'},
#  {'PUlocationID': '-1', 'DOlocationID': '78'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '247'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '20'},
#  {'PUlocationID': '-1', 'DOlocationID': '265'},
#  {'PUlocationID': '-1', 'DOlocationID': '265'},
#  {'PUlocationID': '-1', 'DOlocationID': '147'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '95'},
#  {'PUlocationID': '-1', 'DOlocationID': '10'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '97'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '3'},
#  {'PUlocationID': '-1', 'DOlocationID': '78'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '152'},
#  {'PUlocationID': '-1', 'DOlocationID': '159'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '51'},
#  {'PUlocationID': '-1', 'DOlocationID': '74'},
#  {'PUlocationID': '-1', 'DOlocationID': '10'},
#  {'PUlocationID': '-1', 'DOlocationID': '167'},
#  {'PUlocationID': '-1', 'DOlocationID': '74'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '265'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '126'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '3'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '212'},
#  {'PUlocationID': '-1', 'DOlocationID': '41'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '42'},
#  {'PUlocationID': '-1', 'DOlocationID': '243'},
#  {'PUlocationID': '-1', 'DOlocationID': '116'},
#  {'PUlocationID': '-1', 'DOlocationID': '256'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '217'},
#  {'PUlocationID': '-1', 'DOlocationID': '39'},
#  {'PUlocationID': '-1', 'DOlocationID': '188'},
#  {'PUlocationID': '-1', 'DOlocationID': '188'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '217'},
#  {'PUlocationID': '-1', 'DOlocationID': '217'},
#  {'PUlocationID': '-1', 'DOlocationID': '36'},
#  {'PUlocationID': '-1', 'DOlocationID': '36'},
#  {'PUlocationID': '-1', 'DOlocationID': '36'},
#  {'PUlocationID': '-1', 'DOlocationID': '39'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '77'},
#  {'PUlocationID': '-1', 'DOlocationID': '134'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '123'},
#  {'PUlocationID': '-1', 'DOlocationID': '217'},
#  {'PUlocationID': '-1', 'DOlocationID': '232'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '174'},
#  {'PUlocationID': '-1', 'DOlocationID': '241'},
#  {'PUlocationID': '-1', 'DOlocationID': '78'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '208'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '250'},
#  {'PUlocationID': '-1', 'DOlocationID': '116'},
#  {'PUlocationID': '-1', 'DOlocationID': '166'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '120'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '159'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '243'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '116'},
#  {'PUlocationID': '-1', 'DOlocationID': '42'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '126'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '174'},
#  {'PUlocationID': '-1', 'DOlocationID': '47'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '147'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '72', 'DOlocationID': '72'},
#  {'PUlocationID': '72', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '236'},
#  {'PUlocationID': '-1', 'DOlocationID': '130'},
#  {'PUlocationID': '-1', 'DOlocationID': '216'},
#  {'PUlocationID': '-1', 'DOlocationID': '216'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '258'},
#  {'PUlocationID': '-1', 'DOlocationID': '191'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '106'},
#  {'PUlocationID': '-1', 'DOlocationID': '130'},
#  {'PUlocationID': '-1', 'DOlocationID': '215'},
#  {'PUlocationID': '-1', 'DOlocationID': '173'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '216'},
#  {'PUlocationID': '-1', 'DOlocationID': '258'},
#  {'PUlocationID': '-1', 'DOlocationID': '215'},
#  {'PUlocationID': '-1', 'DOlocationID': '258'},
#  {'PUlocationID': '-1', 'DOlocationID': '130'},
#  {'PUlocationID': '-1', 'DOlocationID': '201'},
#  {'PUlocationID': '-1', 'DOlocationID': '28'},
#  {'PUlocationID': '-1', 'DOlocationID': '216'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '82'},
#  {'PUlocationID': '-1', 'DOlocationID': '177'},
#  {'PUlocationID': '-1', 'DOlocationID': '130'},
#  {'PUlocationID': '-1', 'DOlocationID': '131'},
#  {'PUlocationID': '-1', 'DOlocationID': '173'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '258'},
#  {'PUlocationID': '-1', 'DOlocationID': '129'},
#  {'PUlocationID': '-1', 'DOlocationID': '134'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '177'},
#  {'PUlocationID': '-1', 'DOlocationID': '188'},
#  {'PUlocationID': '-1', 'DOlocationID': '177'},
#  {'PUlocationID': '-1', 'DOlocationID': '108'},
#  {'PUlocationID': '-1', 'DOlocationID': '173'},
#  {'PUlocationID': '-1', 'DOlocationID': '129'},
#  {'PUlocationID': '-1', 'DOlocationID': '56'},
#  {'PUlocationID': '-1', 'DOlocationID': '173'},
#  {'PUlocationID': '-1', 'DOlocationID': '70'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '136'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '243'},
#  {'PUlocationID': '-1', 'DOlocationID': '243'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '127'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '10'},
#  {'PUlocationID': '-1', 'DOlocationID': '216'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '215'},
#  {'PUlocationID': '129', 'DOlocationID': '56'},
#  {'PUlocationID': '-1', 'DOlocationID': '26'},
#  {'PUlocationID': '-1', 'DOlocationID': '227'},
#  {'PUlocationID': '-1', 'DOlocationID': '26'},
#  {'PUlocationID': '-1', 'DOlocationID': '67'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '67'},
#  {'PUlocationID': '-1', 'DOlocationID': '22'},
#  {'PUlocationID': '-1', 'DOlocationID': '130'},
#  {'PUlocationID': '-1', 'DOlocationID': '223'},
#  {'PUlocationID': '-1', 'DOlocationID': '130'},
#  {'PUlocationID': '-1', 'DOlocationID': '130'},
#  {'PUlocationID': '-1', 'DOlocationID': '155'},
#  {'PUlocationID': '-1', 'DOlocationID': '130'},
#  {'PUlocationID': '-1', 'DOlocationID': '197'},
#  {'PUlocationID': '-1', 'DOlocationID': '10'},
#  {'PUlocationID': '-1', 'DOlocationID': '120'},
#  {'PUlocationID': '-1', 'DOlocationID': '47'},
#  {'PUlocationID': '-1', 'DOlocationID': '116'},
#  {'PUlocationID': '-1', 'DOlocationID': '47'},
#  {'PUlocationID': '-1', 'DOlocationID': '247'},
#  {'PUlocationID': '-1', 'DOlocationID': '119'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '116'},
#  {'PUlocationID': '-1', 'DOlocationID': '93'},
#  {'PUlocationID': '-1', 'DOlocationID': '92'},
#  {'PUlocationID': '-1', 'DOlocationID': '129'},
#  {'PUlocationID': '-1', 'DOlocationID': '196'},
#  {'PUlocationID': '-1', 'DOlocationID': '170'},
#  {'PUlocationID': '-1', 'DOlocationID': '93'},
#  {'PUlocationID': '-1', 'DOlocationID': '129'},
#  {'PUlocationID': '-1', 'DOlocationID': '232'},
#  {'PUlocationID': '-1', 'DOlocationID': '121'},
#  {'PUlocationID': '-1', 'DOlocationID': '260'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '41'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '127'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '248'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '127'},
#  {'PUlocationID': '-1', 'DOlocationID': '247'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '250'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '78'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '220'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '165'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '56'},
#  {'PUlocationID': '-1', 'DOlocationID': '21'},
#  {'PUlocationID': '-1', 'DOlocationID': '82'},
#  {'PUlocationID': '-1', 'DOlocationID': '152'},
#  {'PUlocationID': '-1', 'DOlocationID': '119'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '152'},
#  {'PUlocationID': '-1', 'DOlocationID': '42'},
#  {'PUlocationID': '-1', 'DOlocationID': '159'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '213'},
#  {'PUlocationID': '-1', 'DOlocationID': '159'},
#  {'PUlocationID': '-1', 'DOlocationID': '247'},
#  {'PUlocationID': '-1', 'DOlocationID': '167'},
#  {'PUlocationID': '-1', 'DOlocationID': '42'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '202'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '97'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '77'},
#  {'PUlocationID': '-1', 'DOlocationID': '192'},
#  {'PUlocationID': '129', 'DOlocationID': '76'},
#  {'PUlocationID': '56', 'DOlocationID': '70'},
#  {'PUlocationID': '226', 'DOlocationID': '226'},
#  {'PUlocationID': '173', 'DOlocationID': '173'},
#  {'PUlocationID': '129', 'DOlocationID': '129'},
#  {'PUlocationID': '56', 'DOlocationID': '173'},
#  {'PUlocationID': '129', 'DOlocationID': '260'},
#  {'PUlocationID': '56', 'DOlocationID': '56'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '126'},
#  {'PUlocationID': '-1', 'DOlocationID': '167'},
#  {'PUlocationID': '-1', 'DOlocationID': '247'},
#  {'PUlocationID': '92', 'DOlocationID': '56'},
#  {'PUlocationID': '92', 'DOlocationID': '92'},
#  {'PUlocationID': '92', 'DOlocationID': '92'},
#  {'PUlocationID': '73', 'DOlocationID': '227'},
#  {'PUlocationID': '51', 'DOlocationID': '171'},
#  {'PUlocationID': '-1', 'DOlocationID': '21'},
#  {'PUlocationID': '-1', 'DOlocationID': '22'},
#  {'PUlocationID': '-1', 'DOlocationID': '21'},
#  {'PUlocationID': '-1', 'DOlocationID': '21'},
#  {'PUlocationID': '-1', 'DOlocationID': '108'},
#  {'PUlocationID': '-1', 'DOlocationID': '21'},
#  {'PUlocationID': '-1', 'DOlocationID': '21'},
#  {'PUlocationID': '-1', 'DOlocationID': '107'},
#  {'PUlocationID': '-1', 'DOlocationID': '188'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '265'},
#  {'PUlocationID': '-1', 'DOlocationID': '227'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '247'},
#  {'PUlocationID': '-1', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '155'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '178'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '71'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '188'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '55', 'DOlocationID': '-1'},
#  {'PUlocationID': '55', 'DOlocationID': '-1'},
#  {'PUlocationID': '123', 'DOlocationID': '-1'},
#  {'PUlocationID': '150', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '200'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '243'},
#  {'PUlocationID': '-1', 'DOlocationID': '243'},
#  {'PUlocationID': '-1', 'DOlocationID': '177'},
#  {'PUlocationID': '210', 'DOlocationID': '-1'},
#  {'PUlocationID': '123', 'DOlocationID': '-1'},
#  {'PUlocationID': '210', 'DOlocationID': '-1'},
#  {'PUlocationID': '21', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '119'},
#  {'PUlocationID': '-1', 'DOlocationID': '69'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '119'},
#  {'PUlocationID': '-1', 'DOlocationID': '119'},
#  {'PUlocationID': '-1', 'DOlocationID': '20'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '198'},
#  {'PUlocationID': '-1', 'DOlocationID': '93'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '198'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '102'},
#  {'PUlocationID': '-1', 'DOlocationID': '56'},
#  {'PUlocationID': '-1', 'DOlocationID': '198'},
#  {'PUlocationID': '-1', 'DOlocationID': '235'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '147'},
#  {'PUlocationID': '-1', 'DOlocationID': '147'},
#  {'PUlocationID': '-1', 'DOlocationID': '47'},
#  {'PUlocationID': '-1', 'DOlocationID': '32'},
#  {'PUlocationID': '-1', 'DOlocationID': '74'},
#  {'PUlocationID': '-1', 'DOlocationID': '167'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '74'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '41'},
#  {'PUlocationID': '-1', 'DOlocationID': '42'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '208'},
#  {'PUlocationID': '-1', 'DOlocationID': '20'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '221', 'DOlocationID': '245'},
#  {'PUlocationID': '245', 'DOlocationID': '221'},
#  {'PUlocationID': '221', 'DOlocationID': '115'},
#  {'PUlocationID': '115', 'DOlocationID': '206'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '-1', 'DOlocationID': '41'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '74'},
#  {'PUlocationID': '-1', 'DOlocationID': '159'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '74'},
#  {'PUlocationID': '-1', 'DOlocationID': '10'},
#  {'PUlocationID': '-1', 'DOlocationID': '167'},
#  {'PUlocationID': '-1', 'DOlocationID': '74'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '126'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '3'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '177'},
#  {'PUlocationID': '-1', 'DOlocationID': '188'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '49'},
#  {'PUlocationID': '-1', 'DOlocationID': '71'},
#  {'PUlocationID': '-1', 'DOlocationID': '177'},
#  {'PUlocationID': '-1', 'DOlocationID': '10'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '62'},
#  {'PUlocationID': '-1', 'DOlocationID': '39'},
#  {'PUlocationID': '-1', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '97'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '188'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '77'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '177'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '39'},
#  {'PUlocationID': '-1', 'DOlocationID': '233'},
#  {'PUlocationID': '-1', 'DOlocationID': '85'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '49'},
#  {'PUlocationID': '-1', 'DOlocationID': '123'},
#  {'PUlocationID': '-1', 'DOlocationID': '71'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '77'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '177'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '37'},
#  {'PUlocationID': '-1', 'DOlocationID': '122'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '71'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '62'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '85'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '25'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '91'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '133'},
#  {'PUlocationID': '-1', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '227'},
#  {'PUlocationID': '-1', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '22'},
#  {'PUlocationID': '-1', 'DOlocationID': '39'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '22'},
#  {'PUlocationID': '-1', 'DOlocationID': '22'},
#  {'PUlocationID': '-1', 'DOlocationID': '22'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '80'},
#  {'PUlocationID': '-1', 'DOlocationID': '173'},
#  {'PUlocationID': '-1', 'DOlocationID': '173'},
#  {'PUlocationID': '-1', 'DOlocationID': '146'},
#  {'PUlocationID': '-1', 'DOlocationID': '56'},
#  {'PUlocationID': '-1', 'DOlocationID': '20'},
#  {'PUlocationID': '-1', 'DOlocationID': '198'},
#  {'PUlocationID': '-1', 'DOlocationID': '36'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '216'},
#  {'PUlocationID': '-1', 'DOlocationID': '173'},
#  {'PUlocationID': '-1', 'DOlocationID': '173'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '85'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '47'},
#  {'PUlocationID': '-1', 'DOlocationID': '47'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '129'},
#  {'PUlocationID': '-1', 'DOlocationID': '177'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '198'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '182'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '47'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '78'},
#  {'PUlocationID': '-1', 'DOlocationID': '60'},
#  {'PUlocationID': '-1', 'DOlocationID': '74'},
#  {'PUlocationID': '-1', 'DOlocationID': '10'},
#  {'PUlocationID': '-1', 'DOlocationID': '265'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '167'},
#  {'PUlocationID': '-1', 'DOlocationID': '74'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '244'},
#  {'PUlocationID': '-1', 'DOlocationID': '51'},
#  {'PUlocationID': '-1', 'DOlocationID': '174'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '126'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '3'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '215'},
#  {'PUlocationID': '-1', 'DOlocationID': '265'},
#  {'PUlocationID': '-1', 'DOlocationID': '254'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '18'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '259'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '22'},
#  {'PUlocationID': '115', 'DOlocationID': '245'},
#  {'PUlocationID': '245', 'DOlocationID': '221'},
#  {'PUlocationID': '221', 'DOlocationID': '115'},
#  {'PUlocationID': '115', 'DOlocationID': '206'},
#  {'PUlocationID': '221', 'DOlocationID': '214'},
#  {'PUlocationID': '221', 'DOlocationID': '206'},
#  {'PUlocationID': '115', 'DOlocationID': '245'},
#  {'PUlocationID': '115', 'DOlocationID': '115'},
#  {'PUlocationID': '221', 'DOlocationID': '206'},
#  {'PUlocationID': '206', 'DOlocationID': '156'},
#  {'PUlocationID': '-1', 'DOlocationID': '37'},
#  {'PUlocationID': '-1', 'DOlocationID': '198'},
#  {'PUlocationID': '-1', 'DOlocationID': '177'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '63'},
#  {'PUlocationID': '-1', 'DOlocationID': '149'},
#  {'PUlocationID': '-1', 'DOlocationID': '108'},
#  {'PUlocationID': '-1', 'DOlocationID': '210'},
#  {'PUlocationID': '-1', 'DOlocationID': '89'},
#  {'PUlocationID': '-1', 'DOlocationID': '89'},
#  {'PUlocationID': '-1', 'DOlocationID': '123'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '159'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '159'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '173'},
#  {'PUlocationID': '-1', 'DOlocationID': '129'},
#  {'PUlocationID': '-1', 'DOlocationID': '56'},
#  {'PUlocationID': '-1', 'DOlocationID': '173'},
#  {'PUlocationID': '-1', 'DOlocationID': '70'},
#  {'PUlocationID': '-1', 'DOlocationID': '168'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '36'},
#  {'PUlocationID': '-1', 'DOlocationID': '173'},
#  {'PUlocationID': '-1', 'DOlocationID': '70'},
#  {'PUlocationID': '223', 'DOlocationID': '223'},
#  {'PUlocationID': '7', 'DOlocationID': '7'},
#  {'PUlocationID': '17', 'DOlocationID': '206'},
#  {'PUlocationID': '132', 'DOlocationID': '231'},
#  {'PUlocationID': '-1', 'DOlocationID': '188'},
#  {'PUlocationID': '-1', 'DOlocationID': '71'},
#  {'PUlocationID': '-1', 'DOlocationID': '189'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '85'},
#  {'PUlocationID': '-1', 'DOlocationID': '77'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '36'},
#  {'PUlocationID': '-1', 'DOlocationID': '198'},
#  {'PUlocationID': '-1', 'DOlocationID': '36'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '133'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '22'},
#  {'PUlocationID': '-1', 'DOlocationID': '72'},
#  {'PUlocationID': '-1', 'DOlocationID': '181'},
#  {'PUlocationID': '-1', 'DOlocationID': '49'},
#  {'PUlocationID': '-1', 'DOlocationID': '225'},
#  {'PUlocationID': '-1', 'DOlocationID': '49'},
#  {'PUlocationID': '-1', 'DOlocationID': '61'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '228'},
#  {'PUlocationID': '-1', 'DOlocationID': '14'},
#  {'PUlocationID': '-1', 'DOlocationID': '261'},
#  {'PUlocationID': '-1', 'DOlocationID': '76'},
#  {'PUlocationID': '-1', 'DOlocationID': '195'},
#  {'PUlocationID': '-1', 'DOlocationID': '130'},
#  {'PUlocationID': '-1', 'DOlocationID': '232'},
#  {'PUlocationID': '-1', 'DOlocationID': '139'},
#  {'PUlocationID': '-1', 'DOlocationID': '139'},
#  {'PUlocationID': '-1', 'DOlocationID': '35'},
#  {'PUlocationID': '-1', 'DOlocationID': '17'},
#  {'PUlocationID': '-1', 'DOlocationID': '179'},
#  {'PUlocationID': '233', 'DOlocationID': '140'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '-1'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '94'},
#  {'PUlocationID': '-1', 'DOlocationID': '248'},
#  {'PUlocationID': '-1', 'DOlocationID': '81'},
#  {'PUlocationID': '-1', 'DOlocationID': '212'},
#  {'PUlocationID': '-1', 'DOlocationID': '169'},
#  {'PUlocationID': '-1', 'DOlocationID': '248'},
#  ...]

# %%
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# %%
X_train.shape
# Out:
# (1109826, 525)

# %%
y_train = df.duration.values

# %%
y_train.shape
# Out:
# (1109826,)

# %%
len(dv.feature_names_)
# Out:
# 525

# %% [markdown]
# ## Q5. Training a model
# Now let's use the feature matrix from the previous step to train a model.
#
# - Train a plain linear regression model with default parameters
# - Calculate the RMSE of the model on the training data
#
# What's the RMSE on train?

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)

# %%
mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 10.528519107204962

# %% [markdown]
# ## Q6. Evaluating the model
#
# Now let's apply this model to the validation dataset (Feb 2021).
#
# What's the RMSE on validation?

# %%
def read_data(filename, categorical):
    df = pd.read_parquet(filename)
    
    df['duration'] = df.dropOff_datetime - df.pickup_datetime
    df['duration'] = df.duration.dt.total_seconds() / 60

    df = df[(df.duration >= 1) & (df.duration <= 60)].copy()

    df[categorical] = df[categorical].fillna(-1).astype('int').astype('str')
    
    return df

# %%
val_filename = '../data/fhv_tripdata_2021-02.parquet'
categorical = ['PUlocationID', 'DOlocationID']

df_val = read_data(val_filename, categorical)
df_val
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 1            B00021          2021-02-01 00:55:40 2021-02-01 01:06:20
# 2            B00021          2021-02-01 00:14:03 2021-02-01 00:28:37
# 3            B00021          2021-02-01 00:27:48 2021-02-01 00:35:45
# 4                     B00037 2021-02-01 00:12:50 2021-02-01 00:26:38
# 5                     B00037 2021-02-01 00:00:37 2021-02-01 00:09:35
# ...                      ...                 ...                 ...
# 1037687               B03282 2021-02-28 23:01:16 2021-02-28 23:14:48
# 1037688               B03282 2021-02-28 23:36:10 2021-02-28 23:47:38
# 1037689      B03285          2021-02-28 23:18:36 2021-02-28 23:43:59
# 1037690      B03285          2021-02-28 23:26:34 2021-02-28 23:44:37
# 1037691      B03285          2021-02-28 23:24:00 2021-02-28 23:40:00
#
#         PUlocationID DOlocationID SR_Flag Affiliated_base_number   duration
# 1                173           82    None        B00021           10.666667
# 2                173           56    None        B00021           14.566667
# 3                 82          129    None        B00021            7.950000
# 4                 -1          225    None                 B00037  13.800000
# 5                 -1           61    None                 B00037   8.966667
# ...              ...          ...     ...                    ...        ...
# 1037687           -1           31    None                 B01717  13.533333
# 1037688           -1          169    None                 B01717  11.466667
# 1037689           28          171    None        B03285           25.383333
# 1037690           16          252    None        B03285           18.050000
# 1037691          171          135    None        B03285           16.000000
#
# [990113 rows x 8 columns]

# %%
val_dicts = df_val[categorical].to_dict(orient='records')

# %%
X_val = dv.transform(val_dicts)

# %%
y_pred = lr.predict(X_val)

# %%
y_val = df_val.duration.values

# %%
mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 11.014283150034183
